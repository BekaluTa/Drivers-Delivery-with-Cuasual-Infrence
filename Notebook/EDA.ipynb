# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('white')
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading Data to DF Frame

# %%
Data=pd.read_csv('D:/Tenx Batch 6/Week 9/nb.csv')

# %%
Data
# Out:
#         Trip ID                         Trip Origin  \
# 0        391996  6.508813001668548,3.37740316890347
# 1        391997                 6.4316714,3.4555375
# 2        391998         6.631679399999999,3.3388976
# 3        391999         6.572757200000001,3.3677082
# 4        392001                 6.6010417,3.2766339
# ...         ...                                 ...
# 536015  1637696         6.448218499999999,3.4772075
# 536016  1637702         6.442320899999999,3.4736868
# 536017  1637704                  6.4281982,3.492248
# 536018  1637705                 6.5869296,3.3632966
# 536019  1637709         6.647209999999999,3.4851489
#
#                             Trip Destination      Trip Start Time  \
# 0                6.650969799999999,3.3450307  2021-07-01 07:28:04
# 1            6.4280814653326,3.4721885847586  2021-07-01 06:38:04
# 2                6.508324099999999,3.3590397  2021-07-01 06:21:02
# 3                6.584881099999999,3.3614073  2021-07-01 07:16:07
# 4                        6.4501069,3.3916154  2021-07-01 09:30:59
# ...                                      ...                  ...
# 536015   6.437787399999999,3.481670199999999  2021-12-30 20:35:06
# 536016  6.436589333407897,3.5559738188407835  2021-12-30 20:48:13
# 536017           6.448088500000001,3.4775747  2021-12-30 20:51:45
# 536018           6.637906899999999,3.3339515  2021-12-30 20:48:50
# 536019   6.454915198823159,3.555839938365194  2021-12-30 20:55:38
#
#               Trip End Time
# 0       2021-07-01 07:29:37
# 1       2021-07-01 07:07:28
# 2       2021-07-01 07:02:23
# 3       2021-07-01 07:29:42
# 4       2021-07-01 09:34:36
# ...                     ...
# 536015  2021-12-30 21:02:59
# 536016  2021-12-30 21:43:49
# 536017  2021-12-30 21:41:32
# 536018  2021-12-30 21:08:28
# 536019  2021-12-30 22:25:00
#
# [536020 rows x 5 columns]

# %% [markdown]
# # Checking Data Type and column Infos

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536020 entries, 0 to 536019
# Data columns (total 5 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Trip ID           536020 non-null  int64
#  1   Trip Origin       536020 non-null  object
#  2   Trip Destination  536020 non-null  object
#  3   Trip Start Time   534369 non-null  object
#  4   Trip End Time     536019 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 20.4+ MB

# %% [markdown]
# # Sort Missing Vlaues ascendingly

# %%
Data.isnull().sum().sort_values(ascending=False)
# Out:
# Trip Start Time     1651
# Trip End Time          1
# Trip ID                0
# Trip Origin            0
# Trip Destination       0
# dtype: int64

# %% [markdown]
# # Missing Value Graphical Analysis

# %%
#Identifying and visualizing null values throughout the data
sns.heatmap(Data.isnull())
sns.set(rc={'figure.figsize':(15,7)})# width and height respectivly
plt.xticks(rotation=90)
plt.title('Null value analysis accross all data',size=20)
plt.show()

# %%
# check out rows with missing columns
Data[Data.isnull().any(axis=1)].head()
# Out:
#       Trip ID                      Trip Origin  \
# 665    393193      6.545651599999999,3.3776289
# 1368   394447  6.4371758130759,3.5097476821616
# 1551   394819      6.432360999999999,3.4211614
# 1908   395492      6.594949000000001,3.3399855
# 1943   395549      6.432360999999999,3.4211614
#
#                           Trip Destination Trip Start Time  \
# 665                      6.497595,3.383098             NaN
# 1368                   6.4430658,3.5380258             NaN
# 1551   6.427381234249496,3.483499092984462             NaN
# 1908                    6.6424974,3.501294             NaN
# 1943  6.435587578976596,3.4789828421229885             NaN
#
#             Trip End Time
# 665   2021-07-01 12:45:12
# 1368  2021-07-01 13:05:02
# 1551  2021-07-01 14:57:13
# 1908  2021-07-01 21:54:10
# 1943  2021-07-01 15:20:33

# %%
Data.describe().round(2)
# Out:
#           Trip ID
# count   536020.00
# mean    991022.05
# std     345636.43
# min     391996.00
# 25%     693561.00
# 50%     991008.50
# 75%    1281570.50
# max    1637709.00

# %%
Data_location=pd.read_csv('D:/Tenx Batch 6/Week 9/driver_locations_during_request.csv')

# %%
Data_location.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1557740 entries, 0 to 1557739
# Data columns (total 8 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   id             1557740 non-null  int64
#  1   order_id       1557740 non-null  int64
#  2   driver_id      1557740 non-null  int64
#  3   driver_action  1557740 non-null  object
#  4   lat            1557740 non-null  float64
#  5   lng            1557740 non-null  float64
#  6   created_at     0 non-null        float64
#  7   updated_at     0 non-null        float64
# dtypes: float64(4), int64(3), object(1)
# memory usage: 95.1+ MB

# %%
Data_location
# Out:
#               id  order_id  driver_id driver_action       lat       lng  \
# 0              1    392001     243828      accepted  6.602207  3.270465
# 1              2    392001     243588      rejected  6.592097  3.287445
# 2              3    392001     243830      rejected  6.596133  3.281784
# 3              4    392001     243539      rejected  6.596142  3.280526
# 4              5    392001     171653      rejected  6.609232  3.288800
# ...          ...       ...        ...           ...       ...       ...
# 1557735  1557736    517948     243774      rejected  6.469036  3.566877
# 1557736  1557737    517948     245447      rejected  6.425431  3.527358
# 1557737  1557738    517948     239866      rejected  6.440013  3.525378
# 1557738  1557739    517948     243774      rejected  6.469036  3.566877
# 1557739  1557740    517948     244170      rejected  6.469390  3.572079
#
#          created_at  updated_at
# 0               NaN         NaN
# 1               NaN         NaN
# 2               NaN         NaN
# 3               NaN         NaN
# 4               NaN         NaN
# ...             ...         ...
# 1557735         NaN         NaN
# 1557736         NaN         NaN
# 1557737         NaN         NaN
# 1557738         NaN         NaN
# 1557739         NaN         NaN
#
# [1557740 rows x 8 columns]

# %%
Data.isnull().sum().sort_values(ascending=False)
# Out:
# Trip Start Time     1651
# Trip End Time          1
# Trip ID                0
# Trip Origin            0
# Trip Destination       0
# dtype: int64

# %%
#Identifying and visualizing null values throughout the data
sns.heatmap(Data_location.isnull())
sns.set(rc={'figure.figsize':(15,7)})# width and height respectivly
plt.xticks(rotation=90)
plt.title('Null value analysis accross all data',size=20)
plt.show()

# %%
# check out rows with missing columns
Data_location[Data_location.isnull().any(axis=1)].head()
# Out:
#    id  order_id  driver_id driver_action       lat       lng  created_at  \
# 0   1    392001     243828      accepted  6.602207  3.270465         NaN
# 1   2    392001     243588      rejected  6.592097  3.287445         NaN
# 2   3    392001     243830      rejected  6.596133  3.281784         NaN
# 3   4    392001     243539      rejected  6.596142  3.280526         NaN
# 4   5    392001     171653      rejected  6.609232  3.288800         NaN
#
#    updated_at
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
Data_location.corr()
# Out:
#                   id  order_id  driver_id       lat       lng  created_at  \
# id          1.000000  0.990965   0.026861 -0.017755  0.046669         NaN
# order_id    0.990965  1.000000   0.023262 -0.019077  0.047058         NaN
# driver_id   0.026861  0.023262   1.000000 -0.038278  0.054652         NaN
# lat        -0.017755 -0.019077  -0.038278  1.000000 -0.697142         NaN
# lng         0.046669  0.047058   0.054652 -0.697142  1.000000         NaN
# created_at       NaN       NaN        NaN       NaN       NaN         NaN
# updated_at       NaN       NaN        NaN       NaN       NaN         NaN
#
#             updated_at
# id                 NaN
# order_id           NaN
# driver_id          NaN
# lat                NaN
# lng                NaN
# created_at         NaN
# updated_at         NaN

# %%
#Aanlysing the missing values using percentage out of 100% and visualizing the data
missing=Data.isnull().sum()/len(Data)*100
missing.sort_values(ascending=False).head(50)
# Out:
# Trip Start Time     0.308011
# Trip End Time       0.000187
# Trip ID             0.000000
# Trip Origin         0.000000
# Trip Destination    0.000000
# dtype: float64

# %%
missing.plot.area(stacked=False,figsize=[13,4])
plt.xticks(rotation=75)
plt.title('Messing value percentage analysis',size=20)
plt.style.use('fivethirtyeight')

# %%
New_Data=Data.groupby('Trip ID').sum()

# %%
New_Data
# Out:
#                                 Trip Origin  \
# Trip ID
# 391996   6.508813001668548,3.37740316890347
# 391997                  6.4316714,3.4555375
# 391998          6.631679399999999,3.3388976
# 391999          6.572757200000001,3.3677082
# 392001                  6.6010417,3.2766339
# ...                                     ...
# 1637696         6.448218499999999,3.4772075
# 1637702         6.442320899999999,3.4736868
# 1637704                  6.4281982,3.492248
# 1637705                 6.5869296,3.3632966
# 1637709         6.647209999999999,3.4851489
#
#                              Trip Destination      Trip Start Time  \
# Trip ID
# 391996            6.650969799999999,3.3450307  2021-07-01 07:28:04
# 391997        6.4280814653326,3.4721885847586  2021-07-01 06:38:04
# 391998            6.508324099999999,3.3590397  2021-07-01 06:21:02
# 391999            6.584881099999999,3.3614073  2021-07-01 07:16:07
# 392001                    6.4501069,3.3916154  2021-07-01 09:30:59
# ...                                       ...                  ...
# 1637696   6.437787399999999,3.481670199999999  2021-12-30 20:35:06
# 1637702  6.436589333407897,3.5559738188407835  2021-12-30 20:48:13
# 1637704           6.448088500000001,3.4775747  2021-12-30 20:51:45
# 1637705           6.637906899999999,3.3339515  2021-12-30 20:48:50
# 1637709   6.454915198823159,3.555839938365194  2021-12-30 20:55:38
#
#                Trip End Time
# Trip ID
# 391996   2021-07-01 07:29:37
# 391997   2021-07-01 07:07:28
# 391998   2021-07-01 07:02:23
# 391999   2021-07-01 07:29:42
# 392001   2021-07-01 09:34:36
# ...                      ...
# 1637696  2021-12-30 21:02:59
# 1637702  2021-12-30 21:43:49
# 1637704  2021-12-30 21:41:32
# 1637705  2021-12-30 21:08:28
# 1637709  2021-12-30 22:25:00
#
# [536020 rows x 4 columns]

# %%
New_Data=Data.groupby('Trip ID',as_index=True)['Trip Destination','Trip Origin'].sum().head(20)

# %%
New_Data
# Out:
#                             Trip Destination  \
# Trip ID
# 391996           6.650969799999999,3.3450307
# 391997       6.4280814653326,3.4721885847586
# 391998           6.508324099999999,3.3590397
# 391999           6.584881099999999,3.3614073
# 392001                   6.4501069,3.3916154
# 392005           6.499696300000001,3.3509075
# 392009                    6.6185421,3.301634
# 392013           6.435460000000001,3.4846547
# 392014                   6.4280911,3.5157172
# 392017           6.500039999999999,3.3248596
# 392018   6.641425539975534,3.363795145750658
# 392021           6.429098199999999,3.4238032
# 392022                   6.5386117,3.3218346
# 392024           6.598432600000001,3.3665644
# 392025           6.603051199999999,3.2675017
# 392029                   6.5960236,3.2927065
# 392031           6.468300099999999,3.6389102
# 392033                   6.6383753,3.3331197
# 392035                   6.6209465,3.5114902
# 392036           6.443346099999999,3.4827817
#
#                                    Trip Origin
# Trip ID
# 391996      6.508813001668548,3.37740316890347
# 391997                     6.4316714,3.4555375
# 391998             6.631679399999999,3.3388976
# 391999             6.572757200000001,3.3677082
# 392001                     6.6010417,3.2766339
# 392005             6.565087699999999,3.3844415
# 392009                     6.6636484,3.3082058
# 392013                     6.4308171,3.4341552
# 392014             6.499156300000001,3.3585173
# 392017             6.535043099999999,3.3316238
# 392018                     6.4460709,3.4780352
# 392021                     6.5943334,3.3007843
# 392022                     6.5399034,3.3621329
# 392024      6.51083009077994,3.334218713267063
# 392025     6.430077799999999,3.451058999999999
# 392029             6.509874399999999,3.3290259
# 392031       6.5005854898178,3.358164636697353
# 392033                     6.5214112,3.3672892
# 392035   6.4828782552075905,3.3526801804419786
# 392036                     6.4408899,3.5030541

# %%
New_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 391996 to 392036
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Trip Destination  20 non-null     object
#  1   Trip Origin       20 non-null     object
# dtypes: object(2)
# memory usage: 480.0+ bytes
